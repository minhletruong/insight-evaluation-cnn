# %% [markdown]
# # CIFAR10 - Combination between CNN and Traditional Filters
#
# Our target is to verify if test accuracy will be increased clearly when we combine CNN and Traditional Filters

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), 'Physical GPUs, ', len(logical_gpus), 'Logical GPUs')
    except RuntimeError as e:
        print(e)

print('TF will attempt to allocate only as much GPU memory as needed for the runtime allocations')
# Out:
# TF will attempt to allocate only as much GPU memory as needed for the runtime allocations

# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras as keras
from tensorflow.image import resize

# %% [markdown]
# ### Data with Traditional Filters

# %%
import os

# %%
DATA_DIR = 'C:/Users/MINH LE/Desktop/TraditionalvsCNN/Additional Experiments/minh_dataset/'

list_files = os.listdir(DATA_DIR)
number_files = len(list_files)
list_files
# Out:
# ['cifar10', 'mnist']

# %% [markdown]
# ### CLTP Filter

# %%
import glob, cv2
cltp = []

CLTP_DIR = DATA_DIR + 'cifar10/cltp/train/'
for img in glob.glob(CLTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    cltp.append(n)
    
cltp = np.asarray(cltp, dtype=np.float32)
cltp.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### CSLBP Filter

# %%
cslbp = []

CSLBP_DIR = DATA_DIR + 'cifar10/cslbp/train/'
for img in glob.glob(CSLBP_DIR + '*.jpg'):
    n = cv2.imread(img)
    cslbp.append(n)
    
cslbp = np.asarray(cslbp, dtype=np.float32)
cslbp.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Gaussian Fiter

# %%
gauss_filter = []

GAUSSIAN_DIR = DATA_DIR + 'cifar10/gaussian/train/'
for img in glob.glob(GAUSSIAN_DIR + '*.jpg'):
    n = cv2.imread(img)
    gauss_filter.append(n)
    
gauss_filter = np.asarray(gauss_filter, dtype=np.float32)
gauss_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ###### GLTP Filter

# %%
gltp_filter = []

GLTP_DIR = DATA_DIR + 'cifar10/gltp/train/'
for img in glob.glob(GLTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    gltp_filter.append(n)
    
gltp_filter = np.asarray(gltp_filter, dtype=np.float32)
gltp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Laplacian Filter

# %%
laplacian_filter = []

LAPLACIAN_DIR = DATA_DIR + 'cifar10/laplacian/train/'
for img in glob.glob(LAPLACIAN_DIR + '*.jpg'):
    n = cv2.imread(img)
    laplacian_filter.append(n)
    
laplacian_filter = np.asarray(laplacian_filter, dtype=np.float32)
laplacian_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### LBP Filter

# %%
lbp_filter = []

LBP_DIR = DATA_DIR + 'cifar10/lbp/train/'
for img in glob.glob(LBP_DIR + '*.jpg'):
    n = cv2.imread(img)
    lbp_filter.append(n)
    
lbp_filter = np.asarray(lbp_filter, dtype=np.float32)
lbp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### LTP Filter

# %%
ltp_filter = []

LTP_DIR = DATA_DIR + 'cifar10/ltp/train/'
for img in glob.glob(LTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    ltp_filter.append(n)
    
ltp_filter = np.asarray(ltp_filter, dtype=np.float32)
ltp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### MC-LBP FILTER

# %%
mclbp_filter = []

MCLBP_DIR = DATA_DIR + 'cifar10/mclbp/train/'
for img in glob.glob(MCLBP_DIR + '*.jpg'):
    n = cv2.imread(img)
    mclbp_filter.append(n)
    
mclbp_filter = np.asarray(mclbp_filter, dtype=np.float32)
mclbp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### Prewitt X Filter

# %%
prewittx_filter = []

PREWITTX_DIR = DATA_DIR + 'cifar10/prewittx/train/'
for img in glob.glob(PREWITTX_DIR + '*.jpg'):
    n = cv2.imread(img)
    prewittx_filter.append(n)
    
prewittx_filter = np.asarray(prewittx_filter, dtype=np.float32)
prewittx_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### Prewitt Y Filter

# %%
prewitty_filter = []

PREWITTY_DIR = DATA_DIR + 'cifar10/prewitty/train/'
for img in glob.glob(PREWITTY_DIR + '*.jpg'):
    n = cv2.imread(img)
    prewitty_filter.append(n)
    
prewitty_filter = np.asarray(prewitty_filter, dtype=np.float32)
prewitty_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### SCBP Filter

# %%
scbp_filter = []

SCBP_DIR = DATA_DIR + 'cifar10/scbp/train/'
for img in glob.glob(SCBP_DIR + '*.jpg'):
    n = cv2.imread(img)
    scbp_filter.append(n)
    
scbp_filter = np.asarray(scbp_filter, dtype=np.float32)
scbp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### SCS-LTP FILTER

# %%
scsltp_filter = []

SCSLTP_DIR = DATA_DIR + 'cifar10/scsltp/train/'
for img in glob.glob(SCSLTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    scsltp_filter.append(n)
    
scsltp_filter = np.asarray(scsltp_filter, dtype=np.float32)
scsltp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### SILTP Filter

# %%
siltp_filter = []

SILTP_DIR = DATA_DIR + 'cifar10/siltp/train/'
for img in glob.glob(SILTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    siltp_filter.append(n)
    
siltp_filter = np.asarray(siltp_filter, dtype=np.float32)
siltp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### SOBEL X Filter

# %%
sobelx_filter = []

SOBELX_DIR = DATA_DIR + 'cifar10/sobelx/train/'
for img in glob.glob(SOBELX_DIR + '*.jpg'):
    n = cv2.imread(img)
    sobelx_filter.append(n)
    
sobelx_filter = np.asarray(sobelx_filter, dtype=np.float32)
sobelx_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### SOBEL Y Filter

# %%
sobely_filter = []

SOBELY_DIR = DATA_DIR + 'cifar10/sobely/train/'
for img in glob.glob(SOBELY_DIR + '*.jpg'):
    n = cv2.imread(img)
    sobely_filter.append(n)
    
sobely_filter = np.asarray(sobely_filter, dtype=np.float32)
sobely_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# #### XCSLTP Filter

# %%
xcsltp_filter = []

XCSLTP_DIR = DATA_DIR + 'cifar10/xcsltp/train/'
for img in glob.glob(XCSLTP_DIR + '*.jpg'):
    n = cv2.imread(img)
    xcsltp_filter.append(n)
    
xcsltp_filter = np.asarray(xcsltp_filter, dtype=np.float32)
xcsltp_filter.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Original Data

# %%
cifar10 = tf.keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

train_images = tf.reshape(train_images, (50000, 32, 32, 3))
train_labels = tf.reshape(train_labels, (50000, 1))
print(train_images.shape)
print(train_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels.numpy()[i])
plt.show()
# Out:
# C:\Users\MINH LE\anaconda3\lib\site-packages\matplotlib\text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout

# %%
train_data = np.concatenate([cltp, 
                                            cslbp, 
                                            gauss_filter, 
                                            gltp_filter,
                                            laplacian_filter,
                                            lbp_filter,
                                            ltp_filter,
                                            mclbp_filter,
                                            prewittx_filter,
                                            prewitty_filter,
                                            scsltp_filter,
                                            siltp_filter,
                                            sobelx_filter,
                                            sobely_filter,
                                            xcsltp_filter,
                                            scbp_filter,
                                           train_images], axis=-1)
train_data.shape
# Out:
# (50000, 32, 32, 51)

# %%
from keras.layers import Dense, AvgPool2D
from keras.layers import Flatten, Conv2D, BatchNormalization
from keras.models import Model
from keras.models import Sequential
from tensorflow.keras.layers import concatenate

IMG_SIZE = 32
IMG_CHANNEL = 51

# Le-Net
model = Sequential()
model.add(Conv2D(filters=6, kernel_size=5, activation='relu', padding='same', input_shape=(IMG_SIZE, IMG_SIZE, IMG_CHANNEL)))
model.add(BatchNormalization())
model.add(AvgPool2D(pool_size=2, strides=2))

model.add(Conv2D(filters=16, kernel_size=5, activation='relu'))
model.add(BatchNormalization())
model.add(AvgPool2D(pool_size=2, strides=2))

model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer = 'adam', 
               loss='sparse_categorical_crossentropy',
               metrics = ['accuracy'])

model.summary()

history_data = model.fit(train_data,
          train_labels, 
          epochs=10,
          batch_size=512)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 32, 32, 6)         7656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 6)         24
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 16, 16, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 16)        2416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 16)        64
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               69240
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 90,414
# Trainable params: 90,370
# Non-trainable params: 44
# _________________________________________________________________
# Epoch 1/10
# 98/98 [==============================] - 120s 1s/step - loss: 2.1735 - accuracy: 0.1883
# Epoch 2/10
# 98/98 [==============================] - 120s 1s/step - loss: 1.6098 - accuracy: 0.4199
# Epoch 3/10
# 98/98 [==============================] - 115s 1s/step - loss: 1.3907 - accuracy: 0.4995
# Epoch 4/10
# 98/98 [==============================] - 115s 1s/step - loss: 1.2723 - accuracy: 0.5429
# Epoch 5/10
# 98/98 [==============================] - 120s 1s/step - loss: 1.1898 - accuracy: 0.5781
# Epoch 6/10
# 98/98 [==============================] - 111s 1s/step - loss: 1.1322 - accuracy: 0.5996
# Epoch 7/10
# 98/98 [==============================] - 122s 1s/step - loss: 1.0665 - accuracy: 0.6222
# Epoch 8/10
# 98/98 [==============================] - 119s 1s/step - loss: 1.0271 - accuracy: 0.6388
# Epoch 9/10
# 98/98 [==============================] - 113s 1s/step - loss: 0.9610 - accuracy: 0.6622
# Epoch 10/10
# 98/98 [==============================] - 117s 1s/step - loss: 0.9306 - accuracy: 0.6762

# %%
model.save(r'C:\Users\MINH LE\Desktop\TraditionalvsCNN\Additional Experiments\cifar10\models\model_combined_traditionalcnn_cifar10_t2.h5')
